-- %%
create database day7;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
use day7;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE TABLE Employees (
    emp_id INT PRIMARY KEY,
    name VARCHAR(50),
    department_id INT,
    salary INT,
    manager_id INT
);

-- %%
CREATE TABLE Departments (
    dept_id INT PRIMARY KEY,
    dept_name VARCHAR(50)
);

-- %%
CREATE TABLE Orders (
    order_id INT PRIMARY KEY,
    emp_id INT,
    order_amount INT,
    order_date DATE
);

-- %%
INSERT INTO Employees VALUES
(1, 'Alice', 101, 60000, NULL),
(2, 'Bob', 102, 45000, 1),
(3, 'Charlie', 101, 70000, 1),
(4, 'David', 103, 40000, 2),
(5, 'Eve', 102, 50000, 2);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
INSERT INTO Departments VALUES
(101, 'HR'),
(102, 'IT'),
(103, 'Finance');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %%
INSERT INTO Orders VALUES
(1, 1, 5000, '2024-01-10'),
(2, 2, 3000, '2024-02-15'),
(3, 3, 7000, '2024-03-12'),
(4, 1, 2000, '2024-04-01'),
(5, 4, 1000, '2024-05-05');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
-- Employees earning more than average salary
SELECT *
FROM employees
WHERE salary > (
    SELECT AVG(salary)
    FROM employees
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td><td>60000</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr></tbody></table></div>

-- %%
-- Employees in same department as 'Alice'
SELECT *
FROM employees
WHERE department_id = (
    SELECT department_id
    FROM employees
    WHERE name = 'Alice'
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td><td>60000</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr></tbody></table></div>

-- %%
-- 3. Employees with minimum salary
SELECT *
FROM employees
WHERE salary = (
    SELECT MIN(salary)
    FROM employees
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>4</td><td>David</td><td>103</td><td>40000</td><td>2</td></tr></tbody></table></div>

-- %%
--4. Employees who placed at least one order
SELECT *
FROM employees e
WHERE EXISTS (
    SELECT 1
    FROM orders o
    WHERE o.emp_id = e.emp_id
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td><td>60000</td><td>null</td></tr><tr><td>2</td><td>Bob</td><td>102</td><td>45000</td><td>1</td></tr><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr><tr><td>4</td><td>David</td><td>103</td><td>40000</td><td>2</td></tr></tbody></table></div>

-- %%
-- 5. Employees earning more than ALL in dept 102
SELECT *
FROM employees
WHERE salary > (
    SELECT MAX(salary)
    FROM employees
    WHERE department_id = 102
);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td><td>60000</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr></tbody></table></div>

-- %% [markdown]
-- CTE Questions

-- %%
-- Employees with salary > 50,000
WITH cte_high_salary AS (
    SELECT *
    FROM employees
    WHERE salary > 50000
)
SELECT *
FROM cte_high_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td><td>60000</td><td>null</td></tr><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr></tbody></table></div>

-- %%
-- 2. Average salary per department
WITH cte_avg_salary AS (
    SELECT 
        department_id,
        AVG(salary) AS avg_salary
    FROM employees
    GROUP BY department_id
)
SELECT *
FROM cte_avg_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department_id</th><th>avg_salary</th></tr></thead><tbody><tr><td>101</td><td>65000.0</td></tr><tr><td>102</td><td>47500.0</td></tr><tr><td>103</td><td>40000.0</td></tr></tbody></table></div>

-- %%
-- Employees with department names
WITH cte_emp_dept AS (
    SELECT 
        e.emp_id,
        e.name,
        d.dept_name,
        e.salary
    FROM employees e
    JOIN departments d
        ON e.department_id = d.dept_id
)
SELECT *
FROM cte_emp_dept;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>dept_name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>HR</td><td>60000</td></tr><tr><td>2</td><td>Bob</td><td>IT</td><td>45000</td></tr><tr><td>3</td><td>Charlie</td><td>HR</td><td>70000</td></tr><tr><td>4</td><td>David</td><td>Finance</td><td>40000</td></tr><tr><td>5</td><td>Eve</td><td>IT</td><td>50000</td></tr></tbody></table></div>

-- %%
-- Total order amount per employee
WITH cte_total_orders AS (
    SELECT 
        emp_id,
        SUM(order_amount) AS total_orders
    FROM orders
    GROUP BY emp_id
)
SELECT *
FROM cte_total_orders;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>total_orders</th></tr></thead><tbody><tr><td>1</td><td>7000</td></tr><tr><td>2</td><td>3000</td></tr><tr><td>3</td><td>7000</td></tr><tr><td>4</td><td>1000</td></tr></tbody></table></div>

-- %%
-- Employees above department average
WITH cte_dept_avg AS (
    SELECT 
        department_id,
        AVG(salary) AS avg_salary
    FROM employees
    GROUP BY department_id
)
SELECT e.*
FROM employees e
JOIN cte_dept_avg d
    ON e.department_id = d.department_id
WHERE e.salary > d.avg_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th><th>salary</th><th>manager_id</th></tr></thead><tbody><tr><td>3</td><td>Charlie</td><td>101</td><td>70000</td><td>1</td></tr><tr><td>5</td><td>Eve</td><td>102</td><td>50000</td><td>2</td></tr></tbody></table></div>
